# %%
# !pip install transformers>=4.32.0 optimum>=1.12.0
#!pip install auto-gptq --extra-index-url https://huggingface.github.io/autogptq-index/whl/cu118/
#!pip install -U langchain chromadb
#!pip install -U sentence-transformers
#!pip install unstructured
# !pip install torch

# %% [markdown]
# **Direct test model**

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

model = "tiiuae/falcon-7b"

tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    #device_map="auto",
)
sequences = pipeline(
   "What is diabetes?",
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result: What is diabetes?
# Diabetes is a disease that happens when your body does not make enough insulin, or when your body cannot use the insulin that it makes properly.
# Diabetes has 2 major types:
# - Type 1 diabetes happens when the body cannot make insulin
# - Type 2 diabetes happens when the body can make insulin but does not use it as well as it used to
# What causes diabetes?
# There are several factors that make you more likely to develop diabetes.
# If you have one or more of these factors, you are at risk for developing type 2 diabetes.
# If you have one or more of these factors, you are at risk for developing type 1 diabetes.
# - Being overweight
# - Being physically inactive
# - Family history of diabetes
# - High blood pressure
# - High cholesterol
# ...

# %%
sequences = pipeline(
   "What is diabetes?",
    max_length=500,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result: What is diabetes?
# Diabetes is a disorder of the metabolism in which your body does not use food energy properly. The main feature is that the patient has too much sugar in the blood and the urine.
# Types of Diabetes
# There are two types of diabetes: type 1 and type 2. In type 1 diabetes the pancreas is incapable of producing insulin, so insulin therapy must be given. This form of diabetes usually arises in youth, though it can appear at any age.
# Type 2 diabetes develops slowly and is often caused by obesity, but the pancreas usually produces insulin. It often does not become apparent until the sufferer is older than 40 or 50. Type 2 is the most common form of diabetes.
# Diabetes can lead to serious and potentially fatal complications. The complications can include: heart disease, stroke, blindness, kidney disease, and amputation. Complications can also occur due to the high blood sugar levels.
# ...

# %% [markdown]
# **TRY 2**

# %%
from transformers import pipeline

model = "tiiuae/falcon-7b"

tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    #device_map="auto",
)

while True:
    prompt = input("Enter your question('exit' to stop): ")

    # Check if the user wants to exit the loop
    if prompt.lower() == 'exit':
        print("Exiting the loop.")
        break

    sequences = pipeline(
        prompt,
        max_new_tokens=200,
        do_sample=True,
        top_k=10,
        return_full_text=False,
    )

    for seq in sequences:
        print(f"Result: {seq['generated_text']}")

# %% [markdown]
# **Structure for loop**
#
# **Try 1**

# %%
from transformers import pipeline

# Assuming 'pipe' is your pipeline function for the model
# pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)
model = "tiiuae/falcon-7b"

tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    #device_map="auto",
)

# while True:
#     prompt = input("Enter your question (type 'exit' to stop): ")

#     # Check if the user wants to exit the loop
#     if prompt.lower() == 'exit':
#         print("Exiting the loop.")
#         break

#     sequences = pipeline(
#         prompt,
#         max_new_tokens=200,
#         do_sample=True,
#         top_k=10,
#         return_full_text=False,
#     )

#     for seq in sequences:
#         print(f"Result: {seq['generated_text']}")

# %%
while True:
    question = input("Enter your question (type 'exit' to stop): ")

    # Check if the user wants to exit the loop
    if question.lower() == 'exit':
        print("Exiting the loop.")
        break

    prompt = f"Question: {question}\nAnswer only based on the question above."

    sequences = pipeline(
        prompt,
        max_new_tokens=200,
        do_sample=True,
        top_k=10,
        return_full_text=False,
    )

    for seq in sequences:
        print(f"Result: {seq['generated_text']}")
# Out:
# Enter your question (type 'exit' to stop): what is diabetes?
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result:
# A chronic illness where glucose (sugar) builds up in the body.
# The answer is 'Yes'.
# It is a condition in which blood sugar levels are abnormally high, usually as a result of a failure to properly metabolise glucose.
# The pancreas produces a chemical called insulin which allows glucose to enter cells of the body, where it is used for energy. Diabetes causes glucose to build up in the blood instead.
# The body can't use the glucose so it builds up in the blood and the cells starve. The cells need glucose to make energy to survive. If they don't get enough glucose, the body tries to compensate by breaking down fat instead. This results in the production of ketone bodies, which are acidic and poisonous to the liver.
# ...

# %%
while True:
    question = input("Enter question('exit' to stop): ")

    # Check if the user wants to exit the loop
    if question.lower() == 'exit':
        print("Exiting the loop.")
        break

    sequences = pipeline(
        question,
        max_length=300,
        do_sample=True,
        top_k=10,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
    )

    for seq in sequences:
        print(f"Result: {seq['generated_text']}")
# Out:
# Enter question('exit' to stop): what is diabetes?
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result: what is diabetes?
# Diabetes is the condition that arises when your sugar, or blood glucose, levels get too high. Glucose levels are controlled by a hormone known as insulin, which your pancreas creates. When you eat, or if it becomes too low, your cells don’t receive enough of what they need to function properly, and this causes serious health complications.
# There are two types of diabetes: type 1 and type 2. In type 1 diabetes, your body doesn’t produce insulin, which means you’re unable to control your glucose levels. This is a serious, lifelong condition.
# Type 2 diabetes is the most common form of the condition and is caused if your body doesn’t make enough insulin, or can’t use the insulin you produce well enough. You may not be able to produce enough insulin or use it properly if you’re overweight or obese.
# ...

# %% [markdown]
# -----------------------------------------------------------------------

# %% [markdown]
# -----------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------

# %% [markdown]
# **Understand flow**

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

model = "tiiuae/falcon-7b"

tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    #device_map="auto",
)
sequences = pipeline(
   "The patient is a 40-year-old male presenting with a cough and fever. Based on the symptoms and medical history, a diagnosis of pneumonia is made.\nDaniel: Hello, Girafatron!\nGirafatron:",
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# ...

# %%
sequences = pipeline(
   "You act as the medical profession to diagnose and provide medical advice to patients. \nDaniel: Hello, Girafatron!\nGirafatron:",
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result: You act as the medical profession to diagnose and provide medical advice to patients.
# Daniel: Hello, Girafatron!
# Girafatron: Hi there, Daniel! What's your problem?
# Daniel: I can't seem to get any medical advice in this game. I've asked my doctor for advice, but no matter how I click on her to ask, she just ignores my request!
# Girafatron: What is the doctor's name? Can you send me a screen capture of this?
# Daniel: Of course. Her name is Doctor H.
# Girafatron: Okay, I'll get this looked at as soon as I can.
# Girafatron: I'm sure there's a good reason why you can't receive medical advice. It's probably just a glitch in the game, but I'll look into it. Please be patient.
# Daniel: Thank you

# %%
sequences = pipeline(
   "What are the headache symptom?",
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result: What are the headache symptom?
# The headache symptom of the disease is not a disease itself, but the body's way to protect the body. The headache symptom is an external manifestation of the body's internal disease. It is also an important clinical clue. Headache symptom is a kind of symptom that only the doctor can see, but it can help us understand the nature and degree of the patient's illness.
# Headache symptom classification
# According to the headache symptom, it can be divided into:
# - Headache: Headache is the most typical symptom of headache, especially for migraine. The pain of migraine headache is generally unilateral and pulsatile, with varying degrees of severity. The headache of other headaches is not as obvious as the headache, and there may be other symptoms.
# - Nausea: Nausea is a kind of symptom that may be related to headache, and it is often caused by nausea caused by other factors.
# ...

# %%
sequences = pipeline(
   "Explain what are the diabetes symptom?",
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result: Explain what are the diabetes symptom?
# It is a chronic disease in which the body is unable to use glucose due to the low production of insulin or the body is unable to use insulin to utilize blood glucose. Due to the lack of insulin or its improper utilization, the sugar remains in the blood stream causing a number of health issues.
# What are the common symptoms?
# - Thirst
# One of the most common symptoms of type 2 diabetes is excessive thirst and hunger. This may be the first sign you notice. If this is the case, you should consult your doctor as it might indicate high blood sugar levels.
# The body will begin to feel dehydrated even though you are drinking enough water or juices to feel quenched.
# - Weight loss
# If you’ve just started noticing some weight loss, especially if there are no other apparent reasons for the weight loss, you should visit a doctor as soon as you can.
# ...

# %%
sequences = pipeline(
   "What i need to do when i have chicken pox?",
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result: What i need to do when i have chicken pox?
# Answer:
# You'll need to stay at home - if you have to go out you'll have to wear a face mask
# Stay inside, drink lots of fluids, get plenty of rest. I've read that a bath with oatmeal can help the blisters go down.
# Stay home and drink lots of water.
# Take some chicken soup.
# If you go to school, make sure the nurse knows you have chicken pox.
# Stay in bed and drink lots of fluids.
# You will be contagious until all of the blisters have dried up, usually 4-8 days. Don't get any water in the blisters because of risk of infection. If you are feeling better, you may return to school when you have 2- 3 days of clear skin.
# Drink plenty of fluids, rest and take acetaminophen for fever and pain. Do not take aspirin,

# %%
prompt = """
Answer the question using the context below.
Context: Gazpacho is a cold soup and drink made of raw, blended vegetables. Most gazpacho includes stale bread, tomato, cucumbers, onion, bell peppers, garlic, olive oil, wine vinegar, water, and salt. Northern recipes often include cumin and/or pimentón (smoked sweet paprika). Traditionally, gazpacho was made by pounding the vegetables in a mortar with a pestle; this more laborious method is still sometimes used as it helps keep the gazpacho cool and avoids the foam and silky consistency of smoothie versions made in blenders or food processors.
Question: What modern tool is used to make gazpacho?
Answer:
"""

sequences = pipeline(
    prompt,
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result:
# Answer the question using the context below.
# Context: Gazpacho is a cold soup and drink made of raw, blended vegetables. Most gazpacho includes stale bread, tomato, cucumbers, onion, bell peppers, garlic, olive oil, wine vinegar, water, and salt. Northern recipes often include cumin and/or pimentón (smoked sweet paprika). Traditionally, gazpacho was made by pounding the vegetables in a mortar with a pestle; this more laborious method is still sometimes used as it helps keep the gazpacho cool and avoids the foam and silky consistency of smoothie versions made in blenders or food processors.
# Question: What modern tool is used to make gazpacho?
# Answer:
#
#  I think it's more than a spoon (which might be used in making the "puree" part, but the whole dish is made in a blender. Yeah, I've never heard of a blender making

# %%
prompt = """
Answer the question using the context below.
Context: There are 5 groups of students in the class. Each group has 4 students.
Question:  How many students are there in the class?
Answer:
"""

sequences = pipeline(
    prompt,
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result:
# Answer the question using the context below.
# Context: There are 5 groups of students in the class. Each group has 4 students.
# Question:  How many students are there in the class?
# Answer:
#
# There are 5 * 4 = 20 students in the class
#
#  @user4894, @Deduplicator, @BorisDun, @Deduplicator, @BorisDun, @Deduplicator, @BorisDun, @Deduplicator, @BorisDun : `1 ` -> `3` -> `4` -> etc. `\begin{align}
# \sum\limits_{i=3}^{20}i\cdot\lfloor{i/4}\rfloor\cdot\lfloor{\frac{i-3}{4}}\rfloor
